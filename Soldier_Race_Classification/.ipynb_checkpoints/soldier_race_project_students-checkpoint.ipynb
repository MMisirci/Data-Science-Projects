# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

from sklearn.metrics import make_scorer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder,StandardScaler,PowerTransformer, MinMaxScaler, RobustScaler
from sklearn.model_selection import KFold, cross_val_predict, train_test_split,GridSearchCV,cross_val_score, cross_validate
from sklearn.linear_model import LinearRegression, Lasso, Ridge,ElasticNet
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.metrics import classification_report, confusion_matrix, log_loss, recall_score, f1_score, roc_auc_score
from sklearn.metrics import  accuracy_score, confusion_matrix, classification_report, plot_confusion_matrix
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier,GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.feature_selection import SelectKBest,SelectPercentile,f_classif,f_regression,mutual_info_regression
from xgboost import XGBRegressor, XGBClassifier
from xgboost import plot_importance
from sklearn.impute import SimpleImputer
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.cluster import KElbowVisualizer

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, recall_score, precision_score, f1_score
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV

import missingno as msno

#importing plotly and cufflinks in offline mode
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

import warnings
warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('max_colwidth',200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.7f' % x)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# This function calculates total number of missing values and its percentage for each feature

def perc_miss_values (df):
    miss_number = df.isnull().sum().sort_values(ascending=False)
    miss_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    miss_values = pd.concat([miss_number, miss_percent], axis=1, keys=['Miss_Number', 'Miss_Percent'])
    return miss_values

# %%
# This function gives the summary of missing values and unique values for a given feature

def review_values(col):
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum()/df.shape[0]*100, 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].nunique())
    print(df[col].value_counts(dropna = False))

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df0 = pd.read_csv('ANSUR II MALE Public.csv',encoding='latin-1')
df0.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           70         332                366                1071
# 1           72         312                356                1046
# 2           70         349                393                1053
# 3           68         338                367                 986
# 4           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    685         422          441                   502
# 1                    620         441          447                   490
# 2                    665         462          475                   496
# 3                    640         458          461                   460
# 4                    675         481          505                   612
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                560                             500                      77
# 1                540                             488                      73
# 2                556                             482                      72
# 3                511                             452                      76
# 4                666                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender       Date Installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   1       NaN        1   41        71        180
# 1                   1       NaN        1   35        68        160
# 2                   2       NaN        2   42        68        205
# 3                   1       NaN        1   31        66        175
# 4                   2       NaN        2   21        77        213
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %%
df0.shape
# Out:
# (4082, 108)

# %%
df0.columns
# Out:
# Index(['subjectid', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace',
#        'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs',
#        'WritingPreference'],
#       dtype='object', length=108)

# %%
df1 = pd.read_csv('ANSUR II FEMALE Public.csv',encoding='latin-1')
df1.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# 2                        300               276               450
# 3                        364               276               484
# 4                        320               336               525
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  65               338                        301
# 1                  64               294                        270
# 2                  69               309                        270
# 3                  68               340                        294
# 4                  67               300                        295
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 141                  1011           223            836
# 1                 126                   893           186            900
# 2                 128                   987           204            861
# 3                 144                  1012           253            897
# 4                 135                  1281           284            811
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                587                     476                360
# 1                583                     483                350
# 2                583                     466                384
# 3                599                     471                372
# 4                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1336           274                 922         245         1095
# 1             1440           261                 839         206         1234
# 2             1451           287                 874         223         1226
# 3             1430           269                1008         285         1170
# 4             1362           305                1089         290         1112
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           759                    557                             310
# 1           835                    549                             329
# 2           821                    643                             374
# 3           804                    640                             351
# 4           726                    686                             356
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          35         65             16              220               713
# 1          32         60             23              208               726
# 2          36         65             26              204               790
# 3          38         62             22              244               775
# 4          34         65             18              233               732
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                     91         246                        316
# 1                     91         249                        341
# 2                    100         265                        343
# 3                     97         265                        331
# 4                     88         247                        339
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         265                    517                432
# 1                         247                    468                463
# 2                         262                    488                469
# 3                         309                    529                455
# 4                         260                    596                447
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1028           75                182         184
# 1                 1117           78                187         189
# 2                 1060           84                198         195
# 3                 1069           80                192         186
# 4                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          141                548         191                     314
# 1          138                535         180                     307
# 2          146                588         207                     331
# 3          153                593         206                     332
# 4          140                522         181                     308
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           69         345                388                 966
# 1           60         315                335                1048
# 2           70         356                399                1043
# 3           68         337                402                1029
# 4           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    645         363          399                   435
# 1                    595         340          375                   483
# 2                    655         345          399                   470
# 3                    655         392          435                   469
# 4                    635         428          435                   440
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                496                             447                      55
# 1                532                             492                      69
# 2                530                             469                      64
# 3                520                             478                      67
# 4                491                             441                      63
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      404                  118                335
# 1                      334                  115                302
# 2                      401                  135                325
# 3                      402                  118                357
# 4                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    368                           1268         113
# 1                    345                           1389         110
# 2                    369                           1414         122
# 3                    386                           1329         115
# 4                    358                           1350         116
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              362                   235                   1062
# 1              426                   259                   1014
# 2              398                   258                   1049
# 3              394                   250                   1121
# 4              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender      Date Installation  \
# 0                 152          756  Female  5-Oct-10    Fort Hood
# 1                 155          815  Female  5-Oct-10    Fort Hood
# 2                 162          799  Female  5-Oct-10    Fort Hood
# 3                 173          818  Female  5-Oct-10    Fort Hood
# 4                 152          762  Female  5-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army          Combat Support        92Y               Germany
# 1  Regular Army  Combat Service Support        25U            California
# 2  Regular Army  Combat Service Support        35D                 Texas
# 3  Regular Army  Combat Service Support        25U  District of Columbia
# 4  Regular Army             Combat Arms        42A                 Texas
#
#    SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   2                 NaN        2   26        61        142
# 1                   3             Mexican        3   21        64        120
# 2                   1                 NaN        1   23        68        147
# 3                   8  Caribbean Islander        2   22        66        175
# 4                   1                 NaN        1   45        63        195
#
#   WritingPreference
# 0        Right hand
# 1        Right hand
# 2        Right hand
# 3        Right hand
# 4        Right hand

# %%
df1.shape
# Out:
# (1986, 108)

# %%
pd.DataFrame(df1.columns)
# Out:
#                                   0
# 0                         SubjectId
# 1    abdominalextensiondepthsitting
# 2                    acromialheight
# 3             acromionradialelength
# 4                anklecircumference
# 5                      axillaheight
# 6           balloffootcircumference
# 7                  balloffootlength
# 8                 biacromialbreadth
# 9         bicepscircumferenceflexed
# 10                 bicristalbreadth
# 11                 bideltoidbreadth
# 12               bimalleolarbreadth
# 13                 bitragionchinarc
# 14        bitragionsubmandibulararc
# 15               bizygomaticbreadth
# 16             buttockcircumference
# 17                     buttockdepth
# 18                    buttockheight
# 19                buttockkneelength
# 20           buttockpopliteallength
# 21                calfcircumference
# 22                  cervicaleheight
# 23                     chestbreadth
# 24               chestcircumference
# 25                       chestdepth
# 26                      chestheight
# 27                     crotchheight
# 28            crotchlengthomphalion
# 29   crotchlengthposterioromphalion
# 30                       earbreadth
# 31                        earlength
# 32                    earprotrusion
# 33                  elbowrestheight
# 34                 eyeheightsitting
# 35            footbreadthhorizontal
# 36                       footlength
# 37        forearmcenterofgriplength
# 38       forearmcircumferenceflexed
# 39            forearmforearmbreadth
# 40                forearmhandlength
# 41              functionalleglength
# 42                      handbreadth
# 43                handcircumference
# 44                       handlength
# 45                      headbreadth
# 46                headcircumference
# 47                       headlength
# 48           heelanklecircumference
# 49                      heelbreadth
# 50                       hipbreadth
# 51                hipbreadthsitting
# 52               iliocristaleheight
# 53            interpupillarybreadth
# 54                       interscyei
# 55                      interscyeii
# 56             kneeheightmidpatella
# 57                kneeheightsitting
# 58   lateralfemoralepicondyleheight
# 59           lateralmalleolusheight
# 60          lowerthighcircumference
# 61              mentonsellionlength
# 62                neckcircumference
# 63            neckcircumferencebase
# 64    overheadfingertipreachsitting
# 65                       palmlength
# 66                  poplitealheight
# 67             radialestylionlength
# 68            shouldercircumference
# 69              shoulderelbowlength
# 70                   shoulderlength
# 71                    sittingheight
# 72           sleevelengthspinewrist
# 73                    sleeveoutseam
# 74                             span
# 75                          stature
# 76              suprasternaleheight
# 77                   tenthribheight
# 78               thighcircumference
# 79                   thighclearance
# 80                    thumbtipreach
# 81                     tibialheight
# 82                 tragiontopofhead
# 83              trochanterionheight
# 84    verticaltrunkcircumferenceusa
# 85                  waistbacklength
# 86                     waistbreadth
# 87               waistcircumference
# 88                       waistdepth
# 89          waistfrontlengthsitting
# 90             waistheightomphalion
# 91                         weightkg
# 92               wristcircumference
# 93                      wristheight
# 94                           Gender
# 95                             Date
# 96                     Installation
# 97                        Component
# 98                           Branch
# 99                       PrimaryMOS
# 100           SubjectsBirthLocation
# 101              SubjectNumericRace
# 102                       Ethnicity
# 103                         DODRace
# 104                             Age
# 105                        Heightin
# 106                       Weightlbs
# 107               WritingPreference

# %%
print(df0.columns==df1.columns)
# Out:
# [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True]

# %%
df0.columns = df0.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

# %%
df1.columns = df1.columns.str.lower().str.replace('&', '_').str.replace(' ', '_')

# %%
df = df0.append(df1, ignore_index=True)
df.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           70         332                366                1071
# 1           72         312                356                1046
# 2           70         349                393                1053
# 3           68         338                367                 986
# 4           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    685         422          441                   502
# 1                    620         441          447                   490
# 2                    665         462          475                   496
# 3                    640         458          461                   460
# 4                    675         481          505                   612
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                560                             500                      77
# 1                540                             488                      73
# 2                556                             482                      72
# 3                511                             452                      76
# 4                666                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight gender       date installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       component                  branch primarymos subjectsbirthlocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    subjectnumericrace ethnicity  dodrace  age  heightin  weightlbs  \
# 0                   1       NaN        1   41        71        180
# 1                   1       NaN        1   35        68        160
# 2                   2       NaN        2   42        68        205
# 3                   1       NaN        1   31        66        175
# 4                   2       NaN        2   21        77        213
#
#   writingpreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %%
df.shape
# Out:
# (6068, 108)

# %% [markdown]
# Two seprate CSV files are merged into one and one dataframe is created for further analysis.

# %% [markdown]
# ## Explore Data

# %% [markdown]
# There are 99 integer and 9 object type features.

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 108 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    subjectid                       int64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
#  17   buttockdepth                    int64
#  18   buttockheight                   int64
#  19   buttockkneelength               int64
#  20   buttockpopliteallength          int64
#  21   calfcircumference               int64
#  22   cervicaleheight                 int64
#  23   chestbreadth                    int64
#  24   chestcircumference              int64
#  25   chestdepth                      int64
#  26   chestheight                     int64
#  27   crotchheight                    int64
#  28   crotchlengthomphalion           int64
#  29   crotchlengthposterioromphalion  int64
#  30   earbreadth                      int64
#  31   earlength                       int64
#  32   earprotrusion                   int64
#  33   elbowrestheight                 int64
#  34   eyeheightsitting                int64
#  35   footbreadthhorizontal           int64
#  36   footlength                      int64
#  37   forearmcenterofgriplength       int64
#  38   forearmcircumferenceflexed      int64
#  39   forearmforearmbreadth           int64
#  40   forearmhandlength               int64
#  41   functionalleglength             int64
#  42   handbreadth                     int64
#  43   handcircumference               int64
#  44   handlength                      int64
#  45   headbreadth                     int64
#  46   headcircumference               int64
#  47   headlength                      int64
#  48   heelanklecircumference          int64
#  49   heelbreadth                     int64
#  50   hipbreadth                      int64
#  51   hipbreadthsitting               int64
#  52   iliocristaleheight              int64
#  53   interpupillarybreadth           int64
#  54   interscyei                      int64
#  55   interscyeii                     int64
#  56   kneeheightmidpatella            int64
#  57   kneeheightsitting               int64
#  58   lateralfemoralepicondyleheight  int64
#  59   lateralmalleolusheight          int64
#  60   lowerthighcircumference         int64
#  61   mentonsellionlength             int64
#  62   neckcircumference               int64
#  63   neckcircumferencebase           int64
#  64   overheadfingertipreachsitting   int64
#  65   palmlength                      int64
#  66   poplitealheight                 int64
#  67   radialestylionlength            int64
#  68   shouldercircumference           int64
#  69   shoulderelbowlength             int64
#  70   shoulderlength                  int64
#  71   sittingheight                   int64
#  72   sleevelengthspinewrist          int64
#  73   sleeveoutseam                   int64
#  74   span                            int64
#  75   stature                         int64
#  76   suprasternaleheight             int64
#  77   tenthribheight                  int64
#  78   thighcircumference              int64
#  79   thighclearance                  int64
#  80   thumbtipreach                   int64
#  81   tibialheight                    int64
#  82   tragiontopofhead                int64
#  83   trochanterionheight             int64
#  84   verticaltrunkcircumferenceusa   int64
#  85   waistbacklength                 int64
#  86   waistbreadth                    int64
#  87   waistcircumference              int64
#  88   waistdepth                      int64
#  89   waistfrontlengthsitting         int64
#  90   waistheightomphalion            int64
#  91   weightkg                        int64
#  92   wristcircumference              int64
#  93   wristheight                     int64
#  94   gender                          object
#  95   date                            object
#  96   installation                    object
#  97   component                       object
#  98   branch                          object
#  99   primarymos                      object
#  100  subjectsbirthlocation           object
#  101  subjectnumericrace              int64
#  102  ethnicity                       object
#  103  dodrace                         int64
#  104  age                             int64
#  105  heightin                        int64
#  106  weightlbs                       int64
#  107  writingpreference               object
# dtypes: int64(99), object(9)
# memory usage: 5.0+ MB

# %% [markdown]
# The ranges of features are very variable and before modelling phase scaling options shouuld be taken into account.

# %%
df.describe().T
# Out:
#                                       count          mean           std  \
# subjectid                      6068.0000000 20757.1984179 13159.3908939
# abdominalextensiondepthsitting 6068.0000000   246.4686882    37.4001061
# acromialheight                 6068.0000000  1406.1613382    79.0910484
# acromionradialelength          6068.0000000   327.3744232    20.7200182
# anklecircumference             6068.0000000   224.8913975    16.0518333
# cervicaleheight                    452
# acromialheight                     432
# buttockcircumference               429
# suprasternaleheight                427
# chestheight                        421
# axillaheight                       402
# functionalleglength                383
# tenthribheight                     351
# waistheightomphalion               350
# iliocristaleheight                 345
# thighcircumference                 343
# forearmforearmbreadth              335
# buttockheight                      322
# trochanterionheight                321
# crotchheight                       318
# thumbtipreach                      314
# sleevelengthspinewrist             306
# primarymos                         285
# wristheight                        276
# crotchlengthomphalion              273
# date                               253
# sittingheight                      252
# bideltoidbreadth                   244
# interscyei                         240
# bicepscircumferenceflexed          237
# eyeheightsitting                   237
# sleeveoutseam                      226
# interscyeii                        220
# abdominalextensiondepthsitting     218
# waistbreadth                       214
# waistbacklength                    214
# waistdepth                         211
# ethnicity                          209
# buttockkneelength                  209
# neckcircumferencebase              208
# neckcircumference                  206
# lowerthighcircumference            206
# kneeheightsitting                  206
# kneeheightmidpatella               204
# hipbreadthsitting                  202
# calfcircumference                  196
# poplitealheight                    192
# lateralfemoralepicondyleheight     192
# waistfrontlengthsitting            188
# weightlbs                          188
# tibialheight                       187
# buttockpopliteallength             185
# forearmhandlength                  181
# crotchlengthposterioromphalion     180
# elbowrestheight                    176
# forearmcircumferenceflexed         169
# biacromialbreadth                  169
# hipbreadth                         166
# chestdepth                         162
# buttockdepth                       161
# subjectsbirthlocation              152
# forearmcenterofgriplength          143
# shoulderelbowlength                139
# heelanklecircumference             134
# acromionradialelength              133
# bicristalbreadth                   132
# chestbreadth                       131
# bitragionsubmandibulararc          125
# radialestylionlength               124
# headcircumference                  121
# anklecircumference                 112
# thighclearance                     110
# balloffootcircumference            107
# bitragionchinarc                   107
# footlength                         106
# handcircumference                   86
# balloffootlength                    86
# handlength                          79
# wristcircumference                  79
# shoulderlength                      78
# interpupillarybreadth               56
# headlength                          55
# mentonsellionlength                 55
# bizygomaticbreadth                  50
# palmlength                          50
# footbreadthhorizontal               49
# headbreadth                         48
# lateralmalleolusheight              47
# tragiontopofhead                    46
# subjectnumericrace                  44
# heelbreadth                         42
# age                                 42
# handbreadth                         38
# bimalleolarbreadth                  37
# earlength                           36
# heightin                            29
# earprotrusion                       22
# earbreadth                          22
# installation                        12
# dodrace                              7
# branch                               3
# component                            3
# writingpreference                    3
# gender                               2
# dtype: int64

# %%
#There is no duplicate values
df.duplicated().value_counts()
# Out:
# False    6068
# dtype: int64

# %% [markdown]
# Missing values should be evaluated and the features with more missing values should be dropped as they dont provide enough information.

# %%
perc_miss_values (df)
# Out:
#                                 Miss_Number  Miss_Percent
# ethnicity                              4647     0.7658207
# subjectid                                 0     0.0000000
# radialestylionlength                      0     0.0000000
# thighcircumference                        0     0.0000000
# tenthribheight                            0     0.0000000
# suprasternaleheight                       0     0.0000000
# stature                                   0     0.0000000
# span                                      0     0.0000000
# sleeveoutseam                             0     0.0000000
# sleevelengthspinewrist                    0     0.0000000
# sittingheight                             0     0.0000000
# shoulderlength                            0     0.0000000
# shoulderelbowlength                       0     0.0000000
# shouldercircumference                     0     0.0000000
# poplitealheight                           0     0.0000000
# thumbtipreach                             0     0.0000000
# palmlength                                0     0.0000000
# Filipino Korean                                          1
# Blackfoot Mexican                                        1
# Lakota Sioux                                             1
# Cuban Salvadoran                                         1
# Caribbean Islander Dominican                             1
# Azorean                                                  1
# Apache Blackfoot Cherokee Crow                           1
# Name: ethnicity, dtype: int64

# %% [markdown]
# Let us drop ethnicity and subjectid. Because ethnicity has more than 50% missing values and subjectid could be represented by index of the dataframe

# %%
df.drop(['ethnicity','subjectid'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (6068, 106)

# %% [markdown]
# dodrace column contains the information about races. Mainly, there are 6 race types. The rest are stored in 'Other'.
# 1: "White",
# 2: "Black",
# 3: "Hispanic",
# 4: "Asian",
# 5: "Native American",
# 6: "Pacific Islander",
# 8: "Other"
# From the frequency of values in dodrace, it can be seen that white, black and hispanic races are three major races. And the other values would not provide enough information in modelling phase.

# %%
ax=sns.countplot(data=df,x='dodrace')
ax.bar_label(ax.containers[0])
plt.show();

# %% [markdown]
# Now, let us focus on object types. For further analysis, let us evaluate object features with respect to race types.

# %%
df.select_dtypes("object").nunique().sort_values(ascending=False)
# Out:
# primarymos               285
# date                     253
# subjectsbirthlocation    152
# installation              12
# component                  3
# branch                     3
# writingpreference          3
# gender                     2
# dtype: int64

# %%
#convert numeric values to string values
df["dodrace"] = df.dodrace.map({
    1: "White",
    2: "Black",
    3: "Hispanic",
    4: "Asian",
    5: "Native American",
    6: "Pacific Islander",
    8: "Other"
})

# %%
df.groupby(["component"])["dodrace"].value_counts(normalize=True)
# Out:
# component            dodrace
# Army National Guard  White              0.6850074
#                      Black              0.1842688
#                      Hispanic           0.0934269
#                      Asian              0.0221566
#                      Native American    0.0088626
#                      Pacific Islander   0.0062777
# Army Reserve         White              0.5181818
#                      Black              0.2363636
#                      Hispanic           0.1863636
#                      Asian              0.0409091
#                      Pacific Islander   0.0136364
#                      Native American    0.0045455
# Regular Army         White              0.5805732
#                      Black              0.2378981
#                      Hispanic           0.1226115
#                      Asian              0.0378981
#                      Pacific Islander   0.0124204
#                      Native American    0.0076433
#                      Other              0.0009554
# Name: dodrace, dtype: float64

# %%
df.groupby(["component"])["dodrace"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='component,dodrace'>

# %% [markdown]
# The feature of ___'component'___ would provide any information in order to differentiate between 'Regular Army', 'Army Reserve' and 'Army National Guard'. Because, for each value of 'component' it has similar distribution of races. Therefore, it could be dropped.

# %% [markdown]
# Let us add one more dimension to the analysis by adding 'branch'.

# %%
df.groupby(["component", "branch"])["dodrace"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='component,branch,dodrace'>

# %% [markdown]
# For each pair of 'component' and 'branch', similar pattern appears with respect to race distribution. Therefore, there is no gain to keep these object types. Futhermore, "date", "installation" and "primarymos" are irrelavant to race classifications. Let us drop them.

# %%
df.drop(['component','branch','date', 'installation','primarymos'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (6068, 101)

# %%
df.head().T
# Out:
#                                            0          1          2  \
# abdominalextensiondepthsitting           266        233        287
# acromialheight                          1467       1395       1430
# acromionradialelength                    337        326        341
# anklecircumference                       222        220        230
# axillaheight                            1347       1293       1327
# balloffootcircumference                  253        245        256
# balloffootlength                         202        193        196
# biacromialbreadth                        401        394        427
# bicepscircumferenceflexed                369        338        408
# bicristalbreadth                         274        257        261
# bideltoidbreadth                         493        479        544
# bimalleolarbreadth                        71         67         75
# bitragionchinarc                         319        344        345
# bitragionsubmandibulararc                291        320        330
# bizygomaticbreadth                       142        135        135
# buttockcircumference                     979        944       1054
# buttockdepth                             240        232        258
# buttockheight                            882        870        901
# buttockkneelength                        619        584        623
# buttockpopliteallength                   509        468        506
# calfcircumference                        373        357        412
# cervicaleheight                         1535       1471       1501
# chestbreadth                             291        269        288
# chestcircumference                      1074       1021       1120
# chestdepth                               259        253        267
# chestheight                             1292       1244       1288
# crotchheight                             877        851        854
# crotchlengthomphalion                    607        615        636
# crotchlengthposterioromphalion           351        376        359
# earbreadth                                36         33         40
# earlength                                 71         62         61
# earprotrusion                             19         18         23
# elbowrestheight                          247        232        237
# eyeheightsitting                         802        781        810
# footbreadthhorizontal                    101         98        103
# footlength                               273        263        270
# forearmcenterofgriplength                349        348        355
# forearmcircumferenceflexed               299        289        357
# forearmforearmbreadth                    575        523        575
# forearmhandlength                        477        476        491
# functionalleglength                     1136       1096       1115
# handbreadth                               90         86         93
# handcircumference                        214        203        220
# handlength                               193        195        203
# headbreadth                              150        146        148
# headcircumference                        583        568        573
# headlength                               206        201        202
# heelanklecircumference                   326        334        356
# heelbreadth                               70         72         70
# hipbreadth                               332        312        349
# hipbreadthsitting                        366        356        393
# iliocristaleheight                      1071       1046       1053
# interpupillarybreadth                    685        620        665
# interscyei                               422        441        462
# interscyeii                              441        447        475
# kneeheightmidpatella                     502        490        496
# kneeheightsitting                        560        540        556
# lateralfemoralepicondyleheight           500        488        482
# lateralmalleolusheight                    77         73         72
# lowerthighcircumference                  391        371        409
# mentonsellionlength                      118        131        123
# neckcircumference                        400        380        403
# neckcircumferencebase                    436        420        434
# overheadfingertipreachsitting           1447       1380       1447
# palmlength                               113        118        121
# poplitealheight                          437        417        431
# radialestylionlength                     273        254        268
# shouldercircumference                   1151       1119       1276
# shoulderelbowlength                      368        353        367
# shoulderlength                           145        141        167
# sittingheight                            928        884        917
# sleevelengthspinewrist                   883        868        910
# sleeveoutseam                            600        564        604
# span                                    1782       1745       1867
# stature                                 1776       1702       1735
# suprasternaleheight                     1449       1387       1438
# tenthribheight                          1092       1076       1105
# thighcircumference                       610        572        685
# thighclearance                           164        169        198
# thumbtipreach                            786        822        807
# tibialheight                             491        476        477
# tragiontopofhead                         140        120        125
# trochanterionheight                      919        918        918
# verticaltrunkcircumferenceusa           1700       1627       1678
# waistbacklength                          501        432        472
# waistbreadth                             329        316        329
# waistcircumference                       933        870        964
# waistdepth                               240        225        255
# waistfrontlengthsitting                  440        371        411
# waistheightomphalion                    1054       1054       1041
# weightkg                                 815        726        929
# wristcircumference                       175        167        180
# wristheight                              853        815        831
# gender                                  Male       Male       Male
# subjectsbirthlocation           North Dakota   New York   New York
# subjectnumericrace                         1          1          2
# dodrace                                White      White      Black
# age                                       41         35         42
# heightin                                  71         68         68
# weightlbs                                180        160        205
# writingpreference                 Right hand  Left hand  Left hand
#
#                                          3               4
# abdominalextensiondepthsitting         234             250
# acromialheight                        1347            1585
# acromionradialelength                  310             372
# anklecircumference                     230             247
# axillaheight                          1239            1478
# balloffootcircumference                262             267
# balloffootlength                       199             224
# biacromialbreadth                      401             435
# bicepscircumferenceflexed              359             356
# bicristalbreadth                       262             263
# bideltoidbreadth                       518             524
# bimalleolarbreadth                      73              80
# bitragionchinarc                       328             340
# bitragionsubmandibulararc              309             310
# bizygomaticbreadth                     143             138
# buttockcircumference                   991            1029
# buttockdepth                           242             275
# buttockheight                          821            1080
# buttockkneelength                      560             706
# buttockpopliteallength                 437             567
# calfcircumference                      395             425
# cervicaleheight                       1423            1684
# chestbreadth                           296             304
# chestcircumference                    1114            1048
# chestdepth                             262             232
# chestheight                           1205            1452
# crotchheight                           769            1014
# crotchlengthomphalion                  590             682
# crotchlengthposterioromphalion         341             382
# earbreadth                              39              32
# earlength                               66              56
# earprotrusion                           25              19
# elbowrestheight                        272             188
# eyeheightsitting                       794             814
# footbreadthhorizontal                  106             111
# footlength                             267             305
# forearmcenterofgriplength              352             399
# forearmcircumferenceflexed             318             324
# forearmforearmbreadth                  593             605
# forearmhandlength                      467             550
# functionalleglength                   1034            1279
# handbreadth                             91              94
# handcircumference                      217             222
# handlength                             194             218
# headbreadth                            158             153
# headcircumference                      576             566
# headlength                             199             197
# heelanklecircumference                 341             374
# heelbreadth                             68              69
# hipbreadth                             338             332
# hipbreadthsitting                      367             372
# iliocristaleheight                     986            1251
# interpupillarybreadth                  640             675
# interscyei                             458             481
# interscyeii                            461             505
# kneeheightmidpatella                   460             612
# kneeheightsitting                      511             666
# lateralfemoralepicondyleheight         452             585
# lateralmalleolusheight                  76              85
# lowerthighcircumference                393             458
# mentonsellionlength                    106             135
# neckcircumference                      407             398
# neckcircumferencebase                  446             430
# overheadfingertipreachsitting         1357            1572
# palmlength                             118             132
# poplitealheight                        393             523
# radialestylionlength                   249             302
# shouldercircumference                 1155            1231
# shoulderelbowlength                    330             400
# shoulderlength                         148             180
# sittingheight                          903             919
# sleevelengthspinewrist                 848             995
# sleeveoutseam                          550             641
# span                                  1708            2035
# stature                               1655            1914
# suprasternaleheight                   1346            1596
# tenthribheight                        1021            1292
# thighcircumference                     604             672
# thighclearance                         180             194
# thumbtipreach                          803             962
# tibialheight                           445             584
# tragiontopofhead                       127             122
# trochanterionheight                    847            1090
# verticaltrunkcircumferenceusa         1625            1679
# waistbacklength                        461             467
# waistbreadth                           315             303
# waistcircumference                     857             868
# waistdepth                             205             214
# waistfrontlengthsitting                399             379
# waistheightomphalion                   968            1245
# weightkg                               794             946
# wristcircumference                     176             188
# wristheight                            793             954
# gender                                Male            Male
# subjectsbirthlocation            Wisconsin  North Carolina
# subjectnumericrace                       1               2
# dodrace                              White           Black
# age                                     31              21
# heightin                                66              77
# weightlbs                              175             213
# writingpreference               Right hand      Right hand

# %% [markdown]
# In dataframe, there are 'weightlbs' and 'weightkg'. Let us drop 'weightlbs'.

# %%
df.drop(['weightlbs'],axis=1,inplace=True)

# %% [markdown]
# 'subjectnumericrace' information is not necessary since there is 'dodrace'. Let us drop it.

# %%
df.subjectnumericrace.value_counts()
# Out:
# 1        3561
# 2        1026
# 3         541
# 31        160
# 51        126
# 8         116
# 4         109
# 21         60
# 6          59
# 41         46
# 61         35
# 23         34
# 28         26
# 251        20
# 5          18
# 18         18
# 25         14
# 351        10
# 38          9
# 64          8
# 62          8
# 35          8
# 42          7
# 63          7
# 231         6
# 43          5
# 235         4
# 218         3
# 651         2
# 2351        2
# 318         2
# 641         2
# 451         2
# 423         2
# 431         2
# 2518        2
# 48          1
# 631         1
# 4251        1
# 428         1
# 238         1
# 358         1
# 425         1
# 42351       1
# Name: subjectnumericrace, dtype: int64

# %%
df.drop(['subjectnumericrace'],axis=1,inplace=True)

# %% [markdown]
# 'age' and 'writingpreference' has nothing with race classifications. Let us drop both of them.

# %%
df.drop(['age','writingpreference'],axis=1,inplace=True)

# %% [markdown]
# Finally, let us reduce the race values to 'white', 'black' and 'hispanic'.

# %%
df= df[(df["dodrace"] == "White") | (df["dodrace"] == "Black") | (df["dodrace"] == "Hispanic")]
df.head().T
# Out:
#                                            0         1         2          3  \
# abdominalextensiondepthsitting           266       233       287        234
# acromialheight                          1467      1395      1430       1347
# acromionradialelength                    337       326       341        310
# anklecircumference                       222       220       230        230
# axillaheight                            1347      1293      1327       1239
# balloffootcircumference                  253       245       256        262
# balloffootlength                         202       193       196        199
# biacromialbreadth                        401       394       427        401
# bicepscircumferenceflexed                369       338       408        359
# bicristalbreadth                         274       257       261        262
# bideltoidbreadth                         493       479       544        518
# bimalleolarbreadth                        71        67        75         73
# bitragionchinarc                         319       344       345        328
# bitragionsubmandibulararc                291       320       330        309
# bizygomaticbreadth                       142       135       135        143
# buttockcircumference                     979       944      1054        991
# buttockdepth                             240       232       258        242
# buttockheight                            882       870       901        821
# buttockkneelength                        619       584       623        560
# buttockpopliteallength                   509       468       506        437
# calfcircumference                        373       357       412        395
# cervicaleheight                         1535      1471      1501       1423
# chestbreadth                             291       269       288        296
# chestcircumference                      1074      1021      1120       1114
# chestdepth                               259       253       267        262
# chestheight                             1292      1244      1288       1205
# crotchheight                             877       851       854        769
# crotchlengthomphalion                    607       615       636        590
# crotchlengthposterioromphalion           351       376       359        341
# earbreadth                                36        33        40         39
# earlength                                 71        62        61         66
# earprotrusion                             19        18        23         25
# elbowrestheight                          247       232       237        272
# eyeheightsitting                         802       781       810        794
# footbreadthhorizontal                    101        98       103        106
# footlength                               273       263       270        267
# forearmcenterofgriplength                349       348       355        352
# forearmcircumferenceflexed               299       289       357        318
# forearmforearmbreadth                    575       523       575        593
# forearmhandlength                        477       476       491        467
# functionalleglength                     1136      1096      1115       1034
# handbreadth                               90        86        93         91
# handcircumference                        214       203       220        217
# handlength                               193       195       203        194
# headbreadth                              150       146       148        158
# headcircumference                        583       568       573        576
# headlength                               206       201       202        199
# heelanklecircumference                   326       334       356        341
# heelbreadth                               70        72        70         68
# hipbreadth                               332       312       349        338
# hipbreadthsitting                        366       356       393        367
# iliocristaleheight                      1071      1046      1053        986
# interpupillarybreadth                    685       620       665        640
# interscyei                               422       441       462        458
# interscyeii                              441       447       475        461
# kneeheightmidpatella                     502       490       496        460
# kneeheightsitting                        560       540       556        511
# lateralfemoralepicondyleheight           500       488       482        452
# lateralmalleolusheight                    77        73        72         76
# lowerthighcircumference                  391       371       409        393
# mentonsellionlength                      118       131       123        106
# neckcircumference                        400       380       403        407
# neckcircumferencebase                    436       420       434        446
# overheadfingertipreachsitting           1447      1380      1447       1357
# palmlength                               113       118       121        118
# poplitealheight                          437       417       431        393
# radialestylionlength                     273       254       268        249
# shouldercircumference                   1151      1119      1276       1155
# shoulderelbowlength                      368       353       367        330
# shoulderlength                           145       141       167        148
# sittingheight                            928       884       917        903
# sleevelengthspinewrist                   883       868       910        848
# sleeveoutseam                            600       564       604        550
# span                                    1782      1745      1867       1708
# stature                                 1776      1702      1735       1655
# suprasternaleheight                     1449      1387      1438       1346
# tenthribheight                          1092      1076      1105       1021
# thighcircumference                       610       572       685        604
# thighclearance                           164       169       198        180
# thumbtipreach                            786       822       807        803
# tibialheight                             491       476       477        445
# tragiontopofhead                         140       120       125        127
# trochanterionheight                      919       918       918        847
# verticaltrunkcircumferenceusa           1700      1627      1678       1625
# waistbacklength                          501       432       472        461
# waistbreadth                             329       316       329        315
# waistcircumference                       933       870       964        857
# waistdepth                               240       225       255        205
# waistfrontlengthsitting                  440       371       411        399
# waistheightomphalion                    1054      1054      1041        968
# weightkg                                 815       726       929        794
# wristcircumference                       175       167       180        176
# wristheight                              853       815       831        793
# gender                                  Male      Male      Male       Male
# subjectsbirthlocation           North Dakota  New York  New York  Wisconsin
# dodrace                                White     White     Black      White
# heightin                                  71        68        68         66
#
#                                              4
# abdominalextensiondepthsitting             250
# acromialheight                            1585
# acromionradialelength                      372
# anklecircumference                         247
# axillaheight                              1478
# balloffootcircumference                    267
# balloffootlength                           224
# biacromialbreadth                          435
# bicepscircumferenceflexed                  356
# bicristalbreadth                           263
# bideltoidbreadth                           524
# bimalleolarbreadth                          80
# bitragionchinarc                           340
# bitragionsubmandibulararc                  310
# bizygomaticbreadth                         138
# buttockcircumference                      1029
# buttockdepth                               275
# buttockheight                             1080
# buttockkneelength                          706
# buttockpopliteallength                     567
# calfcircumference                          425
# cervicaleheight                           1684
# chestbreadth                               304
# chestcircumference                        1048
# chestdepth                                 232
# chestheight                               1452
# crotchheight                              1014
# crotchlengthomphalion                      682
# crotchlengthposterioromphalion             382
# earbreadth                                  32
# earlength                                   56
# earprotrusion                               19
# elbowrestheight                            188
# eyeheightsitting                           814
# footbreadthhorizontal                      111
# footlength                                 305
# forearmcenterofgriplength                  399
# forearmcircumferenceflexed                 324
# forearmforearmbreadth                      605
# forearmhandlength                          550
# functionalleglength                       1279
# handbreadth                                 94
# handcircumference                          222
# handlength                                 218
# headbreadth                                153
# headcircumference                          566
# headlength                                 197
# heelanklecircumference                     374
# heelbreadth                                 69
# hipbreadth                                 332
# hipbreadthsitting                          372
# iliocristaleheight                        1251
# interpupillarybreadth                      675
# interscyei                                 481
# interscyeii                                505
# kneeheightmidpatella                       612
# kneeheightsitting                          666
# lateralfemoralepicondyleheight             585
# lateralmalleolusheight                      85
# lowerthighcircumference                    458
# mentonsellionlength                        135
# neckcircumference                          398
# neckcircumferencebase                      430
# overheadfingertipreachsitting             1572
# palmlength                                 132
# poplitealheight                            523
# radialestylionlength                       302
# shouldercircumference                     1231
# shoulderelbowlength                        400
# shoulderlength                             180
# sittingheight                              919
# sleevelengthspinewrist                     995
# sleeveoutseam                              641
# span                                      2035
# stature                                   1914
# suprasternaleheight                       1596
# tenthribheight                            1292
# thighcircumference                         672
# thighclearance                             194
# thumbtipreach                              962
# tibialheight                               584
# tragiontopofhead                           122
# trochanterionheight                       1090
# verticaltrunkcircumferenceusa             1679
# waistbacklength                            467
# waistbreadth                               303
# waistcircumference                         868
# waistdepth                                 214
# waistfrontlengthsitting                    379
# waistheightomphalion                      1245
# weightkg                                   946
# wristcircumference                         188
# wristheight                                954
# gender                                    Male
# subjectsbirthlocation           North Carolina
# dodrace                                  Black
# heightin                                    77

# %%
df.shape
# Out:
# (5769, 97)

# %%
#the index should be reset
df.reset_index(drop=True, inplace=True)

# %%
df.tail()
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 5764                             285            1392                    335
# 5765                             262            1324                    301
# 5766                             260            1334                    318
# 5767                             205            1293                    302
# 5768                             238            1346                    308
#
#       anklecircumference  axillaheight  balloffootcircumference  \
# 5764                 223          1297                      252
# 5765                 202          1204                      236
# 5766                 213          1259                      234
# 5767                 199          1207                      213
# 5768                 210          1256                      236
#
#       balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 5764               196                368                        299
# 5765               181                378                        294
# 5766               183                363                        332
# 5767               163                376                        276
# 5768               188                361                        285
#
#       bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 5764               312               477                  72
# 5765               287               468                  66
# 5766               299               460                  70
# 5767               280               426                  62
# 5768               279               433                  71
#
#       bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  \
# 5764               306                        282                 136
# 5765               309                        311                 145
# 5766               317                        311                 139
# 5767               282                        267                 137
# 5768               304                        278                 129
#
#       buttockcircumference  buttockdepth  buttockheight  buttockkneelength  \
# 5764                  1089           255            856                652
# 5765                  1016           246            818                572
# 5766                  1063           262            846                637
# 5767                  1051           225            786                582
# 5768                   974           217            820                586
#
#       buttockpopliteallength  calfcircumference  cervicaleheight  \
# 5764                     541                373             1457
# 5765                     464                375             1390
# 5766                     525                370             1412
# 5767                     480                370             1377
# 5768                     479                343             1401
#
#       chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 5764           290                1082         293         1258           779
# 5765           291                1016         269         1151           732
# 5766           285                1093         286         1166           793
# 5767           270                 922         243         1137           763
# 5768           272                 902         219         1186           783
#
#       crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  \
# 5764                    732                             382          36
# 5765                    647                             331          36
# 5766                    609                             326          39
# 5767                    575                             310          35
# 5768                    536                             307          35
#
#       earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 5764         60             19              210               746
# 5765         65             23              274               770
# 5766         62             18              204               739
# 5767         62             21              222               738
# 5768         58             23              243               754
#
#       footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 5764                    103         259                        328
# 5765                    101         245                        319
# 5766                     97         249                        338
# 5767                     91         226                        306
# 5768                    100         239                        314
#
#       forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 5764                         262                    514                456
# 5765                         261                    514                440
# 5766                         288                    530                459
# 5767                         258                    430                425
# 5768                         259                    464                439
#
#       functionalleglength  handbreadth  handcircumference  handlength  \
# 5764                 1085           81                197         193
# 5765                  985           81                196         183
# 5766                 1050           82                192         191
# 5767                  995           74                177         176
# 5768                 1053           78                187         177
#
#       headbreadth  headcircumference  headlength  heelanklecircumference  \
# 5764          151                582         205                     321
# 5765          160                570         186                     296
# 5766          144                559         190                     318
# 5767          149                558         186                     280
# 5768          148                561         189                     310
#
#       heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 5764           75         381                413                1048
# 5765           61         347                377                 974
# 5766           72         364                400                 986
# 5767           59         369                411                 971
# 5768           78         332                376                 994
#
#       interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 5764                    615         373          390                   462
# 5765                    650         400          411                   433
# 5766                    640         400          412                   450
# 5767                    640         383          418                   432
# 5768                    595         333          373                   444
#
#       kneeheightsitting  lateralfemoralepicondyleheight  \
# 5764                535                             486
# 5765                483                             457
# 5766                517                             476
# 5767                491                             445
# 5768                504                             445
#
#       lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 5764                      61                      423                  121
# 5765                      58                      383                  130
# 5766                      57                      412                  111
# 5767                      58                      400                  119
# 5768                      66                      372                  114
#
#       neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 5764                369                    391                           1307
# 5765                359                    399                           1323
# 5766                352                    402                           1318
# 5767                326                    380                           1286
# 5768                325                    381                           1372
#
#       palmlength  poplitealheight  radialestylionlength  \
# 5764         118              414                   237
# 5765          99              377                   237
# 5766         116              392                   259
# 5767         111              375                   230
# 5768         112              390                   249
#
#       shouldercircumference  shoulderelbowlength  shoulderlength  \
# 5764                   1036                  354             145
# 5765                   1051                  318             142
# 5766                   1054                  338             136
# 5767                    996                  321             136
# 5768                    997                  339             135
#
#       sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  \
# 5764            865                     840            555  1716     1687
# 5765            881                     794            525  1620     1613
# 5766            841                     848            566  1740     1644
# 5767            854                     791            530  1628     1616
# 5768            861                     821            542  1685     1641
#
#       suprasternaleheight  tenthribheight  thighcircumference  thighclearance  \
# 5764                 1391            1119                 660             155
# 5765                 1316            1043                 616             157
# 5766                 1337            1054                 640             159
# 5767                 1288            1028                 623             163
# 5768                 1334            1089                 592             162
#
#       thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  \
# 5764            749           446               136                  872
# 5765            721           422               131                  838
# 5766            758           449               127                  862
# 5767            725           419               135                  802
# 5768            762           436               130                  849
#
#       verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  \
# 5764                           1706              447           334
# 5765                           1648              446           334
# 5766                           1590              444           335
# 5767                           1525              450           298
# 5768                           1547              462           299
#
#       waistcircumference  waistdepth  waistfrontlengthsitting  \
# 5764                1043         265                      370
# 5765                 971         243                      374
# 5766                 982         254                      351
# 5767                 837         208                      335
# 5768                 891         223                      394
#
#       waistheightomphalion  weightkg  wristcircumference  wristheight  gender  \
# 5764                  1002       832                 162          836  Female
# 5765                   958       717                 157          804  Female
# 5766                   970       762                 159          774  Female
# 5767                   952       632                 146          769  Female
# 5768                   943       610                 154          797  Female
#
#      subjectsbirthlocation   dodrace  heightin
# 5764                 Texas  Hispanic        67
# 5765                 Texas  Hispanic        63
# 5766                 Texas     Black        66
# 5767                 Texas  Hispanic        63
# 5768                 Texas  Hispanic        66

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), cmap ="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
X = df.drop("dodrace",axis=1)
X = pd.get_dummies(data=X, drop_first=True)
y = df.dodrace

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101, stratify = y)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4615, 230)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 230)
# Test target shape    :  (1154,)

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# Define evaluation metric function:

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
#set pipeline with parameters
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
pipe_log_model = Pipeline(steps=operations)

# %%
pipe_log_model.fit(X_train,y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240  13   7]
#  [  5 112  19]
#  [ 25  91 642]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.92      0.91       260
#     Hispanic       0.52      0.82      0.64       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 965   40   33]
#  [  23  453   67]
#  [  58  353 2623]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.93      0.93      1038
#     Hispanic       0.54      0.83      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.90      0.88      0.88      4615

# %%
scoring = {"f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"]),
           "precision_Hispanic" : make_scorer(precision_score, average = None, labels =["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"])}

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          0.5925791
# test_precision_Hispanic   0.4868270
# test_recall_Hispanic      0.7623232
# dtype: float64

# %% [markdown]
# __Summary:__ The main focus is to determine hsipanics among others. Recall scores is the main attention. The logistic model indicates that test set has 82% accuracy in predicting hispanics. Moreover, cross validation also supports the robustness of the prediction with racall value of 76%. Now let us make a grid search over logistic model.

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
recall_Hispanic =  make_scorer(recall_score, average=None, labels=["Hispanic"])

# %%
param_grid = {
    "log__C": [1, 5, 10],
    'log__penalty': ["l1", "l2"],
    'log__solver': ['liblinear', 'lbfgs'],
}

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)

log_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1, cv=5)

# %%
log_model_grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
log_model_grid.best_params_

# %%
log_model_grid.best_score_

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)

# %%
from yellowbrick.classifier import PrecisionRecallCurve

operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
#["Hispanic"]
viz.score_

# %% [markdown]
# __Summary:__ Grid search has almost similar results. So, let us store the scores to compare model scores at the end.

# %%
y_pred = log_model_grid.predict(X_test)
log_AP = viz.score_["Hispanic"]
log_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
log_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight="balanced",random_state=101))]
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
pipe_svc_model.fit(X_train, y_train)

eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)

# %%
model = Pipeline(steps=operations_svc)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
param_grid = {
    'svc__C': [1,2,3],
    'svc__gamma': ["scale", "auto", 1, 0.1, 0.01]
}

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(class_weight="balanced",random_state=101))]
model = Pipeline(steps=operations_svc)

svm_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1)

# %%
svm_model_grid.fit(X_train, y_train)

# %%
svm_model_grid.best_params_

# %%
svm_model_grid.best_score_

# %%
eval_metric(svm_model_grid, X_train, y_train, X_test, y_test)

# %%
operations_svc = [("scaler", MinMaxScaler()), ("svc", SVC(C=2, class_weight="balanced",random_state=101))]
model = Pipeline(steps=operations_svc)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# __Summary:__ SVC model has similar recall score than logistic model. But, this time precision score a little bit lower. Now, store the scores for final comparision.

# %%
y_pred = svm_model_grid.predict(X_test)

svc_AP = viz.score_["Hispanic"]
svc_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
svc_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 3. RF

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X2 = df.drop("dodrace",axis=1)
y = df.dodrace

# %%
cat = X2.select_dtypes("object").columns
cat

# %%
enc = OrdinalEncoder()
X2[cat] = enc.fit_transform(X2[cat])
X2.head()

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y, test_size=0.2, random_state=101, stratify =y)

# %%
print("Train features shape : ", X_train2.shape)
print("Train target shape   : ", y_train2.shape)
print("Test features shape  : ", X_test2.shape)
print("Test target shape    : ", y_test2.shape)

# %% [markdown]
# ### Vanilla RF Model

# %%
rf_model = RandomForestClassifier(class_weight="balanced", random_state=101)

# %%
rf_model.fit(X_train2, y_train2)

# %%
eval_metric(rf_model, X_train2, y_train2, X_test2, y_test2)

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101)

scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# ### RF Model GridsearchCV

# %%
param_grid = {'n_estimators':[400,500],
             'max_depth':[10,12,14,16]} #'min_samples_split':[18,20,22], 'max_features': ['auto', None, 15, 20]

# %%
rf_model = RandomForestClassifier(class_weight="balanced", random_state=101)
rf_grid_model = GridSearchCV(rf_model,
                             param_grid,
                             verbose=3,
                             scoring=recall_Hispanic,
                             n_jobs=-1)

# %%
rf_grid_model.fit(X_train2,y_train2)

# %%
rf_grid_model.best_params_

# %%
rf_grid_model.best_score_

# %%
eval_metric(rf_grid_model, X_train2, y_train2, X_test2, y_test2)

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=101, max_depth=10, n_estimators = 500)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %% [markdown]
# __Summary:__ RF model recall score for hispanic considerably drops and grid search has not improved it very much. But in this model the precision score is greater than SVC model. Now, store the scores.

# %%
y_pred = rf_grid_model.predict(X_test2)

rf_AP = viz.score_["Hispanic"]
rf_f1 = f1_score(y_test2, y_pred, average=None, labels=["Hispanic"])
rf_recall = recall_score(y_test2, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
import xgboost as xgb

# %%
xgb_model = XGBClassifier(random_state=101)

# %%
#class weight is not available for multi classes. Import new module to balance classes.
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train2)
classes_weights

# %%
comp = pd.DataFrame(classes_weights)

comp["label"] = y_train2.reset_index(drop=True)
comp.groupby("label")[0].value_counts()

# %%
#Assign the weight of each class to its instances
xgb_model.fit(X_train2,y_train2, sample_weight=classes_weights)

# %%
eval_metric(xgb_model, X_train2, y_train2, X_test2, y_test2)

# %%
model = XGBClassifier(random_state=101)
#put into new weights into model with using fit_params
scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10, fit_params={"sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
param_grid = {"n_estimators":[50, 100],
              'max_depth':[1,2],
              "learning_rate": [0.1, 0.3],
              "subsample":[0.8, 1],
              "colsample_bytree":[0.8, 1]}

# %%
xgb_model = XGBClassifier(random_state=101)
xgb_grid_model = GridSearchCV(xgb_model, 
                              param_grid, 
                              scoring=recall_Hispanic, 
                              n_jobs = -1, 
                              verbose = 2).fit(X_train2, y_train2,sample_weight=classes_weights)

# %%
xgb_grid_model.best_params_

# %%
xgb_grid_model.best_score_

# %%
eval_metric(xgb_grid_model, X_train2, y_train2, X_test2, y_test2)

# %%
model = XGBClassifier(learning_rate=0.3, max_depth=1,
              random_state=101, subsample=0.8)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1",
    sample_weight=classes_weights
)
viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %% [markdown]
# __Summary:__ XGBoost model has not improved recall scores for hispanic race detection. Moreover, all scores are not better than logistc and SVC models.

# %%
y_pred = xgb_grid_model.predict(X_test2)

xgb_AP = viz.score_["Hispanic"]
xgb_f1 = f1_score(y_test2, y_pred, average=None, labels=["Hispanic"])
xgb_recall = recall_score(y_test2, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## Comparing Models

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "SVM",  "Random Forest", "XGBoost"],
                        "F1": [log_f1[0], svc_f1[0], rf_f1[0], xgb_f1[0]],
                        "Recall": [log_recall[0], svc_recall[0], rf_recall[0], xgb_recall[0]],
                        "AP": [log_AP, svc_AP, rf_AP, xgb_AP]})

def labels(ax):
    for p in ax.patches:
        width = p.get_width()                        # get bar length
        ax.text(width,                               # set the text at 1 unit right of the bar
                p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                '{:1.3f}'.format(width),             # set variable to display, 2 decimals
                ha = 'left',                         # horizontal alignment
                va = 'center')                       # vertical alignment
    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="AP", ascending=False)
ax=sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()

# %% [markdown]
# __Decision:__ Considering all scores together, logistic model outperforms the other models. Therefore, logistic model would be selected.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
final_model = Pipeline(steps=operations)

# %%
final_model.fit(X, y)

# %%
X.describe()

# %%
#since the number of features is very high, let us generate a sample with average values.
avg_human = X.describe().loc["mean"]
avg_human

# %%
final_model.predict([avg_human])

# %%
y[201]

# %%
final_model.predict(X.loc[[201]])

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

y_pred = final_model.predict(X_test)

matthews_corrcoef(y_test, y_pred)

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %% [markdown]
# Imbalance data labels should be addressed very carefully. One way is to increase the number of samples in order to blance the labels. Another way is to decrease the samples so that there is balanced classes. But, both of them can create problems. The best way is to increase to a certain degreee or decrease to a certain degree so that the effects of under or over sampling would be reduced.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline

# %%
over = SMOTE()
X_over, y_over = over.fit_resample(X_train, y_train)

# %%
X_over.shape

# %%
y_over.value_counts()

# %%
under = RandomUnderSampler()
X_under, y_under = under.fit_resample(X_train, y_train)

# %%
X_under.shape

# %%
y_under.value_counts()

# %%
over = SMOTE(sampling_strategy={"Hispanic": 1000})
under = RandomUnderSampler(sampling_strategy={"White": 2500})

# %%
X_resampled_over, y_resampled_over = over.fit_resample(X_train, y_train)

# %%
y_resampled_over.value_counts()

# %%
X_resampled_under, y_resampled_under = under.fit_resample(X_train, y_train)

# %%
y_resampled_under.value_counts()

# %%
# we are configuring our pipeline steps
steps = [('o', over), ('u', under)]

# create a pipeline that will automatically apply over and under
# sampling in order to steps that we created.
pipeline = imbpipeline(steps=steps)

# we will create new data over X_train and y_train.
# We simply delete some of our samples if its race "white" and we add synthetic samples to "hispanics".
X_resampled, y_resampled = pipeline.fit_resample(X_train, y_train)

# %%
y_resampled.value_counts()

# %%
y_train.value_counts()

# %% [markdown]
# ## Logistic Regression Over/Under Sampling

# %%
operations = [('o', over), ('u', under), ("scaler", MinMaxScaler()), 
              ("log", LogisticRegression(max_iter=10000,random_state=101))]

# %%
smote_pipeline = imbpipeline(steps=operations)

# %%
smote_pipeline.fit(X_train, y_train)

# %%
eval_metric(smote_pipeline, X_train, y_train, X_test, y_test)

# %%
model = imbpipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# #  SHAP

# %% [markdown]
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model_shap = LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101, penalty="l1", solver='saga')
model_shap.fit(X_train_scaled, y_train)

# %%
eval_metric(model_shap, X_train_scaled, y_train, X_test_scaled, y_test)

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101, penalty="l1", solver='saga'))]
model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# The scores improve due to artificial new samplings.

# %% [markdown]
# ## Shap values for all data

# %%
import shap

explainer = shap.Explainer(model_shap, X_train_scaled)

shap_values = explainer.shap_values(X_test_scaled)

shap.summary_plot(shap_values, X_test_scaled, max_display=300,feature_names = X.columns)

# %% [markdown]
# ## SHAP for Feature Selection

# %%
explainer = shap.Explainer(model_shap, X_train_scaled)

shap_values = explainer.shap_values(X_train_scaled)

shap.summary_plot(shap_values, X_train_scaled, max_display=300,feature_names = X.columns)

# %%
hispanic = ["subjectsbirthlocation",  'handlength',  'forearmcircumferenceflexed', "headlength", 'bitragionsubmandibulararc',
            'footbreadthhorizontal',  'bimalleolarbreadth', 'poplitealheight', 'waistdepth', 'tragiontopofhead',
            'bideltoidbreadth', 'neckcircumferencebase', 'biacromialbreadth','buttockheight', 'buttockkneelength', 'earlength', 
            'axillaheight']

# %%
X3 = df[hispanic]
X3 = pd.get_dummies(data=X3, drop_first=True)
y = df.dodrace

# %%
X3.shape

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y, test_size=0.2, random_state=101, stratify =y)

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101,
                                                                    penalty="l1", solver='saga'))]
pipe_shap_model = Pipeline(steps=operations)

# %%
pipe_shap_model.fit(X_train3, y_train3)

# %%
eval_metric(pipe_shap_model, X_train3, y_train3, X_test3, y_test3)

# %%
model = Pipeline(steps=operations)

scores = cross_validate(model, X_train3, y_train3, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %%
from yellowbrick.classifier import PrecisionRecallCurve
model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train3, y_train3)
viz.score(X_test3, y_test3)
viz.show();

# %% [markdown]
# __Summary:__ With new set of features, the recall score is about 76%, which is quite good.

# %% [markdown]
# ## SMOTE for X3 dataset

# %%
operations = [('o', over), ('u', under), ("scaler", MinMaxScaler()), 
              ("log", LogisticRegression(max_iter=10000,random_state=101))]

# %%
smote_pipeline_2 = imbpipeline(steps=operations)

# %%
smote_pipeline_2.fit(X_train3, y_train3)

# %%
eval_metric(smote_pipeline_2, X_train3, y_train3, X_test3, y_test3)

# %%
model = imbpipeline(steps=operations)

scores = cross_validate(model, X_train3, y_train3, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]

# %% [markdown]
# ## Find the best threshold for multiclassification

# %%
y2 = y.map({"Hispanic":1, "White":0, "Black":0})

# %%
y2

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(X3, y2, test_size=0.2, random_state=101, stratify =y2)

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
pipe_shap_model2 = Pipeline(steps=operations)

# %%
pipe_shap_model2.fit(X_train4, y_train4)

# %%
eval_metric(pipe_shap_model2, X_train4, y_train4, X_test4, y_test4)

# %%
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, roc_auc_score, auc, roc_curve, average_precision_score, precision_recall_curve

operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(max_iter=10000,random_state=101))]
log_basic_model = Pipeline(steps=operations)

log_basic_model.fit(X_train4, y_train4)
plot_precision_recall_curve(log_basic_model, X_train4, y_train4);

# %%
y_pred_proba = log_basic_model.predict_proba(X_train4)
average_precision_score(y_train4, y_pred_proba[:,1])

# %%
precisions, recalls, thresholds = precision_recall_curve(y_train4, y_pred_proba[:,1])

# %%
optimal_idx = np.argmax((2 * precisions * recalls) / (precisions + recalls))
optimal_threshold = thresholds[optimal_idx]
optimal_threshold

# %%
y_pred2 = pd.Series(pipe_shap_model2.predict_proba(X_test4)[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)

# %%
print(confusion_matrix(y_test4,y_pred2))
print(classification_report(y_test4,y_pred2))

# %%
y_train_pred2 = pd.Series(pipe_shap_model2.predict_proba(X_train4)[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)
print(confusion_matrix(y_train4, y_train_pred2))
print(classification_report(y_train4, y_train_pred2))

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

def CV(n, est, X, y, optimal_threshold):
    skf = StratifiedKFold(n_splits = n, shuffle = True, random_state = 42)
    acc_scores = []
    pre_scores = []
    rec_scores = []
    f1_scores  = []
    
    X = X.reset_index(drop=True)
    y = y.reset_index(drop=True)
    
    for train_index, test_index in skf.split(X, y):
        
        X_train = X.loc[train_index]
        y_train = y.loc[train_index]
        X_test = X.loc[test_index]
        y_test = y.loc[test_index]
        
        
        est = est
        est.fit(X_train, y_train)
        y_pred = est.predict(X_test)
        y_pred_proba = est.predict_proba(X_test)
             
        y_pred2 = pd.Series(y_pred_proba[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)
        
        acc_scores.append(accuracy_score(y_test, y_pred2))
        pre_scores.append(precision_score(y_test, y_pred2, pos_label=1))
        rec_scores.append(recall_score(y_test, y_pred2, pos_label=1))
        f1_scores.append(f1_score(y_test, y_pred2, pos_label=1))
    
    print(f'Accuracy {np.mean(acc_scores)*100:>10,.2f}%  std {np.std(acc_scores)*100:.2f}%')
    print(f'Precision-1 {np.mean(pre_scores)*100:>7,.2f}%  std {np.std(pre_scores)*100:.2f}%')
    print(f'Recall-1 {np.mean(rec_scores)*100:>10,.2f}%  std {np.std(rec_scores)*100:.2f}%')
    print(f'F1_score-1 {np.mean(f1_scores)*100:>8,.2f}%  std {np.std(f1_scores)*100:.2f}%')

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
model = Pipeline(steps=operations)
CV(10, model, X_train4, y_train4, optimal_threshold)

# %% [markdown]
# After feature selection and reducing , the recall score for hispanic has increased to

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
